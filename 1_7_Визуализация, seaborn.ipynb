# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
g=pd.read_csv("genome_matrix.csv",index_col=0)
g=sns.heatmap(g,cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
Dota_T=pd.read_csv("dota_hero_stats.csv")
Dota_T.columns
# Out:
# Index(['Unnamed: 0', 'attack_type', 'id', 'legs', 'localized_name', 'name',
#        'primary_attr', 'roles'],
#       dtype='object')

# %%
Dota_T
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
Dota_T.roles.map(lambda x:x.split(",")).hist()
# Out:
# <Axes: >

# %%
Dota_T.roles.map(lambda x:len(x.split(","))).mode()
# Out:
# 0    4
# Name: roles, dtype: int64

# %%
T=Dota_T.roles.map(lambda x:len(x))
T.mean()
# Out:
# 42.46153846153846

# %%
Iris=pd.read_csv("iris.csv")
Iris
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
sns.histplot(Iris['sepal length'])
# Out:
# <Axes: xlabel='sepal length', ylabel='Count'>

# %%
Iris = Iris.drop(['Unnamed: 0'], axis = 1)

# %%
for i in Iris.columns:
    sns.kdeplot(Iris[i])
    plt.legend(Iris.iloc[:, 0:-1].columns)

# %%
Iris.iloc[0:3,1:]
# Out:
#    sepal width  petal length  petal width  species
# 0          3.5           1.4          0.2        0
# 1          3.0           1.4          0.2        0
# 2          3.2           1.3          0.2        0
